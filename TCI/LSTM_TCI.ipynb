# %%
#  STEP 1: Install dependencies
# ! pip install rasterio tensorflow scikit-learn tqdm

#  STEP 2: Imports
import os
import numpy as np
import rasterio
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from sklearn.preprocessing import MinMaxScaler
from tqdm import tqdm
import matplotlib.pyplot as plt

#  STEP 3: Load all TCI GeoTIFFs into a 3D array

folder = "..\BTP-TCI\GEE-Exports-to_predict_July_2022"
#folder = "..\BTP-TCI\GEE-Exports-to_predict_Jan_2023"
#folder = "..\BTP-TCI\GEE-Exports-to_predict_July_2023"
#folder = "..\BTP-TCI\GEE-Exports-to_predict_Jan_2024"
#folder = "..\BTP-TCI\GEE-Exports-to_predict_July_2024"
#folder = "..\BTP-TCI\GEE-Exports-to_predict_Jan_2025"
files = sorted([f for f in os.listdir(folder) if f.endswith('.tif')])
print(files)

# print(files)
# exit()

TCI_stack = []

print("Reading TCI images...")
# for f in tqdm(files):
#     with rasterio.open(os.path.join(folder, f)) as src:
#         TCI_read = src.read(1)  # Reads the first band (common for TCI)
#         profile = src.profile
#         print(TCI_read, "\n\n\n\n\n")
#         TCI_stack.append(TCI_read)

# # print(TCI_stack)
# TCI_stack = np.array(TCI_stack)  # Shape: [time, height, width]
# time, height, width = TCI_stack.shape

# print(f"Loaded TCI stack with shape: {TCI_stack.shape}")

# for f in files:
#     with rasterio.open(os.path.join(folder, f)) as src:
#         data = src.read(1).astype('float32')
#         nan_count = np.isnan(data).sum()
#         valid_count = np.count_nonzero(~np.isnan(data))

#         unique = np.unique(data)

#         print(np.nanmin(unique))
#         print(np.nanmax(unique))

#         print("NaN values:", nan_count)
#         print("Valid (non-NaN) values:", valid_count)
#         print(src.nodata)
#         ref_mask = np.isnan(data)
#         break

# for f in files[1:]:
#     with rasterio.open(os.path.join(folder, f)) as src:
#         data = src.read(1).astype('float32')
#         nan_count = np.isnan(data).sum()
#         valid_count = np.count_nonzero(~np.isnan(data))

#         unique = np.unique(data)

#         print(np.nanmin(unique))
#         print(np.nanmax(unique))

#         print("NaN values:", nan_count)
#         print("Valid (non-NaN) values:", valid_count)
#         print(src.nodata)
#         current_mask = np.isnan(data)
#         if not np.array_equal(ref_mask, current_mask):
#             print(f"Inconsistent NaN positions in file: {f}")
#             consistent = False
#             break


for f in files:
    with rasterio.open(os.path.join(folder, f)) as src:
        data = src.read(1).astype('float32')
        TCI_stack.append(data)

print(type(TCI_stack[0]))
TCI_stack = np.array(TCI_stack)  # Shape: [time, height, width]
time, height, width = TCI_stack.shape

print(f"Loaded TCI stack with shape: {TCI_stack.shape}")

print("TCI shape:", TCI_stack.shape)
print("TCI stats:", np.nanmin(TCI_stack), np.nanmax(TCI_stack))
# Out:
# <>:16: SyntaxWarning: invalid escape sequence '\B'
# <>:16: SyntaxWarning: invalid escape sequence '\B'
# C:\Users\DELL\AppData\Local\Temp\ipykernel_27120\1243894169.py:16: SyntaxWarning: invalid escape sequence '\B'
#   folder = "..\BTP-TCI\GEE-Exports-to_predict_July_2022"
# ['tci_2022_01.tif', 'tci_2022_02.tif', 'tci_2022_03.tif', 'tci_2022_04.tif', 'tci_2022_05.tif', 'tci_2022_06.tif']
# Reading TCI images...
# <class 'numpy.ndarray'>
# Loaded TCI stack with shape: (6, 5308, 5811)
# TCI shape: (6, 5308, 5811)
# TCI stats: 0.0 1.0

# %%
TCI_stack

for i, layer in enumerate(TCI_stack):
    nans = np.isnan(layer).sum()
    print(f"Time step {i}: {nans} NaN values")

total_nans = np.isnan(TCI_stack).sum()
print("Total NaN values in TCI stack:", total_nans)

total_pixels = np.prod(TCI_stack.shape)
nan_percentage = (total_nans / total_pixels) * 100
print(f"Percentage of NaN values: {nan_percentage:.2f}%")
# Out:
# Time step 0: 21023606 NaN values
# Time step 1: 21023606 NaN values
# Time step 2: 21023606 NaN values
# Time step 3: 21023606 NaN values
# Time step 4: 21023606 NaN values
# Time step 5: 21023606 NaN values
# Total NaN values in TCI stack: 126141636
# Percentage of NaN values: 68.16%

# %%
nan_masks = np.isnan(TCI_stack)  # (time, height, width)
print(nan_masks.shape)

# --- Check where all time steps are NaN ---
consistent_nan_mask = np.all(nan_masks, axis=0)  # (height, width)
consistent_nan_count = np.sum(consistent_nan_mask)
print("Pixels that are NaN in ALL timesteps:", consistent_nan_count)

# --- Optional: visualize consistent NaN locations ---
plt.figure(figsize=(8, 6))
plt.imshow(consistent_nan_mask, cmap='viridis')
plt.title("Pixels NaN in ALL Time Steps")
plt.colorbar(label="1 = Always NaN, 0 = Not Always NaN")
plt.tight_layout()
plt.show()
# Out:
# (6, 5308, 5811)
# Pixels that are NaN in ALL timesteps: 21023606

# %%
TCI_scaled = np.empty_like(TCI_stack, dtype=np.float32)
mins = np.full((height, width), np.nan, dtype=np.float32)
maxs = np.full((height, width), np.nan, dtype=np.float32)

print("Normalizing pixels with NumPy...")
for i in tqdm(range(height)):
    for j in range(width):
        series = TCI_stack[:, i, j]
        if np.isnan(series).any() or np.all(series == 0):
            TCI_scaled[:, i, j] = np.nan
            continue
        min_val = np.nanmin(series)
        max_val = np.nanmax(series)
        if max_val - min_val == 0:
            TCI_scaled[:, i, j] = np.nan
        else:
            TCI_scaled[:, i, j] = (series - min_val) / (max_val - min_val)
            mins[i, j] = min_val
            maxs[i, j] = max_val
# Out:
# Normalizing pixels with NumPy...
# 100%|██████████| 5308/5308 [21:28<00:00,  4.12it/s]

# %%
import os
import numpy as np
import rasterio
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Input, Concatenate
from sklearn.preprocessing import MinMaxScaler
from tqdm import tqdm
import matplotlib.pyplot as plt



normalized=True
seq_length = 5  # Use 5 months to predict the 6th
X_all = []
y_all = []
coords_all = []
# valid_mask = np.ones((height, width), dtype=bool)
# for t in range(time):
#     valid_mask = valid_mask & ~np.isnan(TCI_scaled[t])
print("Preparing training data...")
for i in tqdm(range(height)):
    for j in range(width):
        # if not valid_mask[i, j]:
        #     continue
        if normalized:
            series=TCI_scaled[:, i, j]
        else:
            series = TCI_stack[:, i, j]
        if np.isnan(series).any():
            continue
            
        # Use first 5 months to predict the 6th month
        X_all.append(series[:seq_length])
        y_all.append(series[seq_length])
        coords_all.append([i, j])

# Convert to numpy arrays and reshape for LSTM
X_all = np.array(X_all).reshape(-1, seq_length, 1)
y_all = np.array(y_all)
coords_all = np.array(coords_all)

print(f"Training data prepared: X shape: {X_all.shape}, y shape: {y_all.shape}")
# Out:
# Preparing training data...
# 100%|██████████| 5308/5308 [04:53<00:00, 18.10it/s]
# Training data prepared: X shape: (9819386, 5, 1), y shape: (9819386,)

# %%
def create_lstm_model(seq_length):
    pixel_input = Input(shape=(seq_length, 1))  # TCI time series input
    coord_input = Input(shape=(2,))  # Pixel coordinates (i, j)
    
    # LSTM layers
    # lstm_1 = LSTM(50, return_sequences=True)(pixel_input)
    lstm_1 = LSTM(32, return_sequences=True)(pixel_input)
    lstm_2 = LSTM(50)(lstm_1)
    
    # Concatenate LSTM output with coordinates for spatial awareness
    concat = Concatenate()([lstm_2, coord_input])
    
    # Output layer
    output = Dense(1)(concat)
    
    # Define the model
    model = tf.keras.Model(inputs=[pixel_input, coord_input], outputs=output)
    model.compile(optimizer='adam', loss='mse')
    
    return model

print("Training LSTM model...")
model = create_lstm_model(seq_length)
model.fit(
    [X_all,coords_all], 
    y_all,
    validation_split = 0.2,
    epochs=5, 
    batch_size=2048, 
    verbose=1
)
model_path = "TCI_lstm_model_normalized.keras"
model.save(model_path)
# Out:
# Training LSTM model...
# Epoch 1/5
# 3836/3836 ━━━━━━━━━━━━━━━━━━━━ 347s 89ms/step - loss: 24908.7461 - val_loss: 0.1324
# Epoch 2/5
# 3836/3836 ━━━━━━━━━━━━━━━━━━━━ 447s 106ms/step - loss: 0.1280 - val_loss: 0.1293
# Epoch 3/5
# 3836/3836 ━━━━━━━━━━━━━━━━━━━━ 393s 102ms/step - loss: 0.1210 - val_loss: 0.1064
# Epoch 4/5
# 3836/3836 ━━━━━━━━━━━━━━━━━━━━ 376s 85ms/step - loss: 0.1055 - val_loss: 0.4070
# Epoch 5/5
# 3836/3836 ━━━━━━━━━━━━━━━━━━━━ 317s 82ms/step - loss: 0.1021 - val_loss: 0.0690

# %%
predicted = np.full((height, width), np.nan, dtype=np.float32)
print("prepring data for Predicting TCI for the 7th month...")
X_test=[]
coords_test = []

for i in tqdm(range(height)):
    for j in range(width):
        if normalized:
            series=TCI_scaled[:,i,j]
        else:
            series = TCI_stack[:, i, j]
        if np.isnan(series).any():
            continue
        
        # Use all 6 months to predict the 7th month

        X_test.append(series[1:])
        coords_test.append([i,j])
        
        # # Inverse transform the prediction to original scale
        # if scalers[i, j] is not None:
        #     predicted[i, j] = scalers[i, j].inverse_transform(pred_scaled.reshape(-1, 1))[0][0]

X_test = np.array(X_test).reshape(-1, seq_length, 1)
coords_test = np.array(coords_test)
# Out:
# prepring data for Predicting TCI for the 7th month...
# 100%|██████████| 5308/5308 [01:56<00:00, 45.51it/s]

# %%
print("predicting for 7th month")
y_pred = model.predict([X_test, coords_test], batch_size=2048, verbose=1)

print("converting back to 2d grid")
print(y_pred.shape)
for idx, (i, j) in tqdm(enumerate(coords_test)):
    if normalized:
        min_val = mins[i, j]
        max_val = maxs[i, j]
        assert not np.isnan(min_val) and not np.isnan(max_val)
        predicted[i, j] = y_pred[idx] * (maxs[i,j]-mins[i,j]) + mins[i,j]
    else:
        predicted[i, j] = y_pred[idx]
# Out:
# predicting for 7th month
# 4795/4795 ━━━━━━━━━━━━━━━━━━━━ 177s 37ms/step
# converting back to 2d grid
# (9819386, 1)
# 0it [00:00, ?it/s]C:\Users\DELL\AppData\Local\Temp\ipykernel_27120\1236541991.py:11: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   predicted[i, j] = y_pred[idx] * (maxs[i,j]-mins[i,j]) + mins[i,j]
# 9819386it [01:45, 92966.34it/s]

# %%
# STEP 6: Save prediction as GeoTIFF
print("Saving prediction to GeoTIFF...")#
# Use last image as template

#July 2022
with rasterio.open(os.path.join(folder, files[-1])) as src:
    profile = src.profile
    profile.update(dtype=rasterio.float32, count=1)
    with rasterio.open("..\\BTP-TCI\\Results\\Results_July_2022\\predicted_TCI_July_2022_normalized.tif", "w", **profile) as dst:
        dst.write(predicted.astype(np.float32), 1)
print("✅ Prediction saved as: predicted_July_2022_normalized.tif")

#Jan 2023
# with rasterio.open(os.path.join(folder, files[-1])) as src:
#     profile = src.profile
#     profile.update(dtype=rasterio.float32, count=1)
#     with rasterio.open("..\\BTP-TCI\\Results\\Results_Jan_2023\\predicted_TCI_Jan_2023_normalized.tif", "w", **profile) as dst:
#         dst.write(predicted.astype(np.float32), 1)
# print("✅ Prediction saved as: predicted_Jan_2023_normalized.tif")

#July 2023
# with rasterio.open(os.path.join(folder, files[-1])) as src:
#     profile = src.profile
#     profile.update(dtype=rasterio.float32, count=1)
#     with rasterio.open("..\\BTP-TCI\\Results\\Results_July_2023\\predicted_TCI_July_2023_normalized.tif", "w", **profile) as dst:
#         dst.write(predicted.astype(np.float32), 1)
# print("✅ Prediction saved as: predicted_July_2023_normalized.tif")

#Jan 2024
# with rasterio.open(os.path.join(folder, files[-1])) as src:
#     profile = src.profile
#     profile.update(dtype=rasterio.float32, count=1)
#     with rasterio.open("..\\BTP-TCI\\Results\\Results_Jan_2023\\predicted_TCI_Jan_2023_normalized.tif", "w", **profile) as dst:
#         dst.write(predicted.astype(np.float32), 1)
# print("✅ Prediction saved as: predicted_Jan_2023_normalized.tif")

#July 2024
# with rasterio.open(os.path.join(folder, files[-1])) as src:
#     profile = src.profile
#     profile.update(dtype=rasterio.float32, count=1)
#     with rasterio.open("..\\BTP-TCI\\Results\\Results_July_2024\\predicted_TCI_July_2024_normalized.tif", "w", **profile) as dst:
#         dst.write(predicted.astype(np.float32), 1)
# print("✅ Prediction saved as: predicted_July_2024_normalized.tif")

#Jan 2025
# with rasterio.open(os.path.join(folder, files[-1])) as src:
#     profile = src.profile
#     profile.update(dtype=rasterio.float32, count=1)
#     with rasterio.open("..\\BTP-TCI\\Results\\Results_Jan_2025\\predicted_TCI_Jan_2025_normalized.tif", "w", **profile) as dst:
#         dst.write(predicted.astype(np.float32), 1)
# print("✅ Prediction saved as: predicted_Jan_2025_normalized.tif")



# STEP 7: Preview the prediction

#July 2022
plt.figure(figsize=(10, 8))
plt.imshow(predicted, cmap='autumn')
plt.colorbar(label='TCI')
plt.title("Predicted TCI - July 2022")
plt.axis('off')
plt.savefig("..\\BTP-TCI\\Results\\Results_July_2022\\predicted_TCI_July_2022.png", dpi=300)
plt.show()

#Jan 2023
# plt.figure(figsize=(10, 8))
# plt.imshow(predicted, cmap='autumn')
# plt.colorbar(label='TCI')
# plt.title("Predicted TCI - Jan 2023")
# plt.axis('off')
# plt.savefig("..\\BTP\\Results\\Results_Jan_2023\\predicted_TCI_Jan_2023.png", dpi=300)
# plt.show()

#July 2023
# plt.figure(figsize=(10, 8))
# plt.imshow(predicted, cmap='autumn')
# plt.colorbar(label='TCI')
# plt.title("Predicted TCI - July 2023")
# plt.axis('off')
# plt.savefig("..\\BTP\\Results\\Results_July_2023\\predicted_TCI_July_2023.png", dpi=300)
# plt.show()

#Jan 2024
# plt.figure(figsize=(10, 8))
# plt.imshow(predicted, cmap='autumn')
# plt.colorbar(label='TCI')
# plt.title("Predicted TCI - Jan 2024")
# plt.axis('off')
# plt.savefig("..\\BTP\\Results\\Results_Jan_2024\\predicted_TCI_Jan_2024.png", dpi=300)
# plt.show()

#July 2024
# plt.figure(figsize=(10, 8))
# plt.imshow(predicted, cmap='autumn')
# plt.colorbar(label='TCI')
# plt.title("Predicted TCI - July 2024")
# plt.axis('off')
# plt.savefig("..\\BTP\\Results\\Results_July_2024\\predicted_TCI_July_2024.png", dpi=300)
# plt.show()

#Jan 2025
# plt.figure(figsize=(10, 8))
# plt.imshow(predicted, cmap='autumn')
# plt.colorbar(label='TCI')
# plt.title("Predicted TCI - Jan 2025")
# plt.axis('off')
# plt.savefig("..\\BTP\\Results\\Results_Jan_2025\\predicted_TCI_Jan_2025.png", dpi=300)
# plt.show()
# Out:
# Saving prediction to GeoTIFF...
# ✅ Prediction saved as: predicted_July_2022_normalized.tif
